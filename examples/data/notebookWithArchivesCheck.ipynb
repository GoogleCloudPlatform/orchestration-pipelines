# %%
# Copyright 2026 Google LLC
#
# Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
#      http://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.
#
# TrivialNotebook.ipynb
# Create this as a new Jupyter Notebook file.

# CELL 1: MARKDOWN
"""
# My Trivial Papermill Notebook

This notebook is a simple example to be run by Papermill via Airflow/Composer.
"""

# CELL 2: CODE (This cell MUST be tagged with "parameters")
# In Jupyter, select this cell, go to the Property Inspector (wrench icon),
# and add a cell tag named "parameters".
# -----------------------------------------------------------------------------
input_path = None
output_path = None
execution_date = "1970-01-01"
test_message = "Default Message"
run_id = 0

print("--- Parameters Received ---")
print(f"input_path: {input_path}")
print(f"output_path: {output_path}")
print(f"execution_date: {execution_date}")
print(f"test_message: {test_message}")
print(f"run_id: {run_id}")
print("---------------------------")

# CELL 3: CODE
"""
# Main work of the notebook

This cell just demonstrates using the parameters.
"""
import time
import random

print(f"Starting trivial task for date: {execution_date}")
print(f"Message for this run ({run_id}): {test_message}")

if input_path:
    print(f"Simulating reading from: {input_path}")
# Normally you might use gcsfs or pandas to read data, e.g.:
# import pandas as pd
# df = pd.read_csv(input_path)

time.sleep(random.randint(5, 15)) # Simulate some work

result = f"Processed data for {execution_date} with run_id {run_id}"
print(result)

if output_path:
    print(f"Simulating writing results to: {output_path}")
    # Normally you might write data, e.g.:
    # with open("output.txt", "w") as f:
    #     f.write(result)
    # And then copy to GCS

print("Trivial task complete.")

# Checking the python dependencies in custom_venv.tar.gz file passed to --archives field
import os
import subprocess

# Path to the expected unpacked archive directory
ARCHIVE_FILE_NAME = "custom_venv.tar.gz"
cwd = os.getcwd()
archive_dir_path = os.path.join(cwd, ARCHIVE_FILE_NAME)

print(f"\n--- Listing contents of '{ARCHIVE_FILE_NAME}' ---")
try:
    archive_contents = subprocess.check_output(['ls', '-lAh'], cwd=archive_dir_path).decode('utf-8')
    print(archive_contents)

    # Check for a specific dependency within the venv
    expected_lib = os.path.join(archive_dir_path, 'lib', 'python3.11', 'site-packages', 'pint')
    print(f"\nChecking for pint library at: {expected_lib}")
    if os.path.exists(expected_lib):
        print(f"SUCCESS: Found expected 'pint' directory.")
    else:
        print(f"FAILURE: Did not find expected 'pint' directory.")

    # Check for a specific dependency within the venv
    expected_lib = os.path.join(archive_dir_path, 'lib', 'python3.11', 'site-packages', 'orjson')
    print(f"\nChecking for orjson library at: {expected_lib}")
    if os.path.exists(expected_lib):
        print(f"SUCCESS: Found expected 'orjson' directory.")
    else:
        print(f"FAILURE: Did not find expected 'orjson' directory.")

except Exception as e:
    print(f"Error listing archive directory contents: {e}")

# CELL 4: MARKDOWN
"""
End of Notebook.
"""
